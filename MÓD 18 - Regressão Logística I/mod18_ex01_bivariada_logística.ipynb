# %% [markdown]
# # Regressão Logística I
# ## Tarefa I
#
# Neste exercício vamos trabalhar com a base "Heart Disease Data Set" disponível no site do [UCI](https://archive.ics.uci.edu/ml/datasets/heart+disease).
#
# Temos 303 indivíduos e vamos utilizar 13 variáveis disponíveis para prever a presença de doença cardíaca na variável ```num```(a 14$^a$ variável).
#
# A descrição das variáveis está recortada abaixo:
# - age: idade do paciente em anos
# - sex: sexo (1 = male; 0 = female)
# - cp: tipo de dor no peito
#   - 1: angina típica
#   - 2: angina atípica
#   - 3: dor não-angina
#   - 4: assintomático
# - trestbps: pressão sanguínea em repouso (em mm Hg na admissão ao hospital
# - chol: colesterol sérico em mg/dl
# - fbs: (açúcar no sangue em jejum > 120 mg/dl) (1 = True; 0 = False)
# - restecg: resultados eletrocardiográficos em repouso
#   - 0: normal
#   - 1: tendo anormalidade da onda ST-T (Inversões de onda T e / ou ST com elevação ou depressão de > 0.05 mV)
#   - 2: mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes
# - thalach: frequência cardíaca máxima alcançada
# - exang: angina induzida por exercício(1 = sim; 0 = não)
# - oldpeak = Depressão de ST induzida por exercício em relação ao repouso
# - slope: Depressão de ST induzida por exercício em relação ao repouso
#   - 1: inclinação ascendente
#   - 2: estável
#   - 3: inclinação descendente
# - ca: número de vasos principais (0-3) coloridos por fluorosopia
# - thal: 3 = normal; 6 = defeito corrigido; 7 = defeito reversível
# - num: diagnóstico de doença cardíaga (status de doença angiográfica)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import statsmodels.formula.api as smf

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'

df = pd.read_csv(url,
                 names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
                        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'])
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
df['flag_doente'] = (df['num'] != 0).astype('int64')
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num  flag_doente
# 0      3.0  0.0  6.0    0            0
# 1      2.0  3.0  3.0    2            1
# 2      2.0  2.0  7.0    1            1
# 3      3.0  0.0  3.0    0            0
# 4      1.0  0.0  3.0    0            0
# ..     ...  ...  ...  ...          ...
# 298    2.0  0.0  7.0    1            1
# 299    2.0  2.0  7.0    2            1
# 300    2.0  1.0  7.0    3            1
# 301    2.0  1.0  3.0    1            1
# 302    1.0    ?  3.0    0            0
#
# [303 rows x 15 columns]

# %% [markdown]
# 1. Monte uma bivariada para a variável ```sex``` com as seguintes estatísticas:
#
# - Número de *saudáveis*
# - Número de *doentes*
# - Total
# - Quantidade média de doentes
# - *Odds*
# - *Odds ratio* (Use o total como referência)
# - Logito (LOG(*Odds*))
# - O LOG do *Odds ratio* (com o total como referência) é chamado de *Weight of Evidence* (WOE). Calcule-o.

# %%
tab_sex = (pd.crosstab(index=df['sex'],
                       columns=df['flag_doente'],
                       margins=True,
                       margins_name='total')
             .rename(index={0:'fem', 1:'masc'},
                     columns={0:'saudável', 1:'doente'}))

tab_sex['média_saudável'] = tab_sex['saudável'] / tab_sex['total']*100
tab_sex['média_doentes'] = tab_sex['doente'] / tab_sex['total']*100

tab_sex['odds'] = tab_sex['doente'] / tab_sex['saudável']
tab_sex['odds_ratio'] = tab_sex['odds'] / tab_sex.loc['total', 'odds']

tab_sex['logito'] = np.log(tab_sex['odds'])
tab_sex['WOE'] = np.log(tab_sex['odds'] / tab_sex.loc['total', 'odds'])

tab_sex
# Out:
# flag_doente  saudável  doente  total  média_saudável  média_doentes      odds  \
# sex
# fem                72      25     97       74.226804      25.773196  0.347222
# masc               92     114    206       44.660194      55.339806  1.239130
# total             164     139    303       54.125413      45.874587  0.847561
#
# flag_doente  odds_ratio    logito       WOE
# sex
# fem            0.409672 -1.057790 -0.892398
# masc           1.461996  0.214410  0.379802
# total          1.000000 -0.165392  0.000000

# %% [markdown]
# 2. Monte uma bivariada para a variável ```age``` com as seguintes estatísticas:
# - Categorize a variável em 5 grupos
# - Calcule as mesmas quantidades calculadas no execício anterior
# - Calcule também o valor médio da variável ```age```

# %%
tab_age = (pd.crosstab(index=df['age'],
                       columns=df['flag_doente'],
                       margins=True,
                       margins_name='total')
             .rename(columns={0:'saudável',
                              1:'doente'}))

tab_age['age_group']= pd.qcut(x=df['age'], q=5)
tab_age = tab_age.set_index('age_group')

tab_age = tab_age.groupby('age_group').agg(func='sum')

tab_age.loc['total'] = tab_age.sum()

tab_age['média_saudável'] = tab_age['saudável'] / tab_age['total']
tab_age['média_doentes'] = tab_age['doente'] / tab_age['total']

tab_age['odds'] = tab_age['doente'] / tab_age['saudável']
tab_age['odds_ratio'] = tab_age['odds'] / tab_age.loc['total', 'odds']

tab_age['logito'] = np.log(tab_age['odds'])
tab_age['WOE'] = np.log(tab_age['odds'] / tab_age.loc['total', 'odds'])

tab_age['mean_age'] = df.groupby(by=pd.qcut(x=df['age'], q=5)).mean()['age']
tab_age.loc['total', 'mean_age'] = df['age'].mean()
tab_age['mean_age'] = round(tab_age['mean_age'])

tab_age
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_15752\68718677.py:24: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tab_age['mean_age'] = df.groupby(by=pd.qcut(x=df['age'], q=5)).mean()['age']
# flag_doente     saudável  doente  total  média_saudável  média_doentes  \
# age_group
# (28.999, 45.0]        41      22     63        0.650794       0.349206
# (45.0, 53.0]          26      40     66        0.393939       0.606061
# (53.0, 58.0]          35      43     78        0.448718       0.551282
# (58.0, 62.0]          37      22     59        0.627119       0.372881
# (62.0, 77.0]          25      12     37        0.675676       0.324324
# total                164     139    303        0.541254       0.458746
#
# flag_doente         odds  odds_ratio    logito       WOE  mean_age
# age_group
# (28.999, 45.0]  0.536585    0.633094 -0.622530 -0.457137      41.0
# (45.0, 53.0]    1.538462    1.815163  0.430783  0.596175      50.0
# (53.0, 58.0]    1.228571    1.449538  0.205852  0.371245      56.0
# (58.0, 62.0]    0.594595    0.701536 -0.519875 -0.354483      60.0
# (62.0, 77.0]    0.480000    0.566331 -0.733969 -0.568577      67.0
# total           0.847561    1.000000 -0.165392  0.000000      54.0

# %% [markdown]
# 3. Visualize a informação da bivariada construída acima através de um gráfico da sua escolha.

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(16,10))

age_labels = ['29-45 anos', '45-53 anos', '53-58 anos', '58-62 anos', '62-77 anos']

for col in tab_age.iloc[:-1, :3]:
    sns.lineplot(x=tab_age.iloc[:-1].index.astype(str),
                 y=tab_age.iloc[:-1][col],
                 ax=axes[0])
axes[0].legend(labels=['Saudáveis', 'Total', 'Doentes'])
axes[0].set_xlabel(xlabel='Faixa etária')
axes[0].set_ylabel(ylabel='Quantidade')
axes[0].set_xticks(range(len(age_labels)))
axes[0].set_xticklabels(labels=age_labels)

for col in tab_age.iloc[:-1, 3:-5]:
    sns.lineplot(x=tab_age.iloc[:-1].index.astype(str),
                 y=tab_age.iloc[:-1][col],
                 ax=axes[1])
axes[1].legend(labels=tab_age.iloc[:-1, 3:-5].columns)
axes[1].set_xlabel(xlabel='Faixa etária')
axes[1].set_ylabel(ylabel='')
axes[1].set_xticks(range(len(age_labels)))
axes[1].set_xticklabels(labels=age_labels)

plt.show()

# %%
plt.close('all')

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(16,10))

age_labels = ['29-45 anos', '45-53 anos', '53-58 anos', '58-62 anos', '62-77 anos']

for col in tab_age.iloc[:-1, 5:-3]:
    sns.lineplot(x=tab_age.iloc[:-1].index.astype(str),
                 y=tab_age.iloc[:-1][col],
                 ax=axes[0])
axes[0].legend(labels=['Odds', 'Odds_ratio'])
axes[0].set_xlabel(xlabel='Faixa etária')
axes[0].set_ylabel(ylabel='')
axes[0].set_xticks(range(len(age_labels)))
axes[0].set_xticklabels(labels=age_labels)

for col in tab_age.iloc[:-1, 7:-1]:
    sns.lineplot(x=tab_age.iloc[:-1].index.astype(str),
                 y=tab_age.iloc[:-1][col],
                 ax=axes[1])
axes[1].legend(labels=tab_age.iloc[:-1, 7:-1].columns)
axes[1].set_xlabel(xlabel='Faixa Etária')
axes[1].set_ylabel(ylabel='')
axes[1].set_xticks(range(len(age_labels)))
axes[1].set_xticklabels(labels=age_labels)

plt.show()
